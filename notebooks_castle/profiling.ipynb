# %%
# autmoatically reload changed modules
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# See if GPUs are available

# %%
# !echo $LD_LIBRARY_PATH
# Out:
# :/home/b/b309247/work/miniconda3/envs/tensorflow_env/lib/:/lib:/home/b/b309247/work/miniconda3/envs/tensorflow_env/lib/:/lib:/home/b/b309247/work/miniconda3/envs/tensorflow_env/lib/:/home/b/b309247/work/miniconda3/envs/tensorflow_env/lib/python3.9/site-packages/nvidia/cudnn/lib

# %%
import tensorflow as tf
# Out:
# 2023-05-17 16:17:05.123058: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-17 16:17:25.220592: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tf.test.is_built_with_cuda()
# Out:
# True

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  4

# %%
# Python script profiling viz with SnakeViz - doesn't work
# %load_ext snakeviz

# %%
import sys
import os

# %%
module_path = os.path.abspath(os.path.join('..'))
# Relative imports
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
output_dir = os.path.join(os.path.abspath(os.path.join('.')), "output")
if not os.path.isdir(output_dir):
    os.mkdir(output_dir)
print(f"Output directory: {output_dir}")
# Out:
# Output directory: /work/bd1179/b309247/pycharm_projects/iglesias-suarez2yxx_spuriouslinks/notebooks_castle/output

# %%
from neural_networks.models import generate_models
from utils.setup import SetupNeuralNetworks

# %%
# %aimport
# Out:
# Modules to reload:
# all-except-skipped
#
# Modules to skip:

# %%
argv = ["-c", os.path.join(module_path, "nn_config", "castle", "cfg_castle_NN_Creation.yml")]

# %%
print(os.path.join(output_dir, "profile_castle_setup_neural_networks.prof"))
# Because prun doesn't expand user variables anymore (e.g. "$out_file"), 
# we have to copy the string and insert it into the prun command (watch the backward/forward slashes!)
# Out:
# /work/bd1179/b309247/pycharm_projects/iglesias-suarez2yxx_spuriouslinks/notebooks_castle/output/profile_castle_setup_neural_networks.prof

# %%
# Note: needs to be run without string quotes
# %prun -D output/profile_castle_setup_neural_networks.prof  SetupNeuralNetworks(argv)
# Out:
#
# *** Profile stats marshalled to file 'output/profile_castle_setup_neural_networks.prof'.
#          120300 function calls (120125 primitive calls) in 0.187 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       130    0.038    0.000    0.038    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#        90    0.034    0.000    0.034    0.000 {built-in method builtins.round}
#         2    0.034    0.017    0.044    0.022 utils.py:70(read_ancilaries)
#         1    0.013    0.013    0.013    0.013 {built-in method io.open}
#         2    0.012    0.006    0.012    0.006 {method 'read' of '_io.TextIOWrapper' objects}
#      8507    0.010    0.000    0.024    0.000 core.py:3211(__getitem__)
#     16948    0.004    0.000    0.007    0.000 core.py:3682(_get_data)
#         6    0.004    0.001    0.007    0.001 utils.py:81(_StartCountStride)
#         1    0.003    0.003    0.109    0.109 utils.py:34(get_gridpoints)
# ...

# %% [markdown]
# To view results run ``snakeviz output_file`` in terminal

# %%
# Get the setup
castle_setup = SetupNeuralNetworks(argv)

# %%
print(os.path.join(output_dir, "profile_castle_generate_models_gpu.prof"))
# Because prun doesn't expand user variables anymore (e.g. "$out_file"), 
# we have to copy the string and insert it into the prun command
# Out:
# /work/bd1179/b309247/pycharm_projects/iglesias-suarez2yxx_spuriouslinks/notebooks_castle/output/profile_castle_generate_models_gpu.prof

# %%
# %prun -D output\profile_castle_generate_models_gpu.prof generate_models(castle_setup)
# Out:
# 2023-05-17 16:22:22.323463: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78839 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:03:00.0, compute capability: 8.0
# 2023-05-17 16:22:22.326042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 78923 MB memory:  -> device: 1, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:44:00.0, compute capability: 8.0
# 2023-05-17 16:22:22.327185: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 78923 MB memory:  -> device: 2, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:84:00.0, compute capability: 8.0
# ...
